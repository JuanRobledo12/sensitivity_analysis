# %%
from utils import GenerateSensitivityAnalysisData
import pandas as pd
import os

# %%
generate_data = GenerateSensitivityAnalysisData(experiment_data_path='experiment_data', time_period=7)

# %%
df = generate_data.create_CSVs_for_sensitivity_analysis()
df
# Out:
#      exports_lvst_cattle_nondairy  exports_lvst_sheep  exports_lvst_chickens  \
# 0                    10542.010791         1026.556959           93951.037000
# 1                    16440.955501         1232.030668          126546.817402
# 2                     8539.259728         1007.047501          136104.189245
# 3                    12719.302517         1351.813132           80875.327639
# 4                    17374.445338         1335.965293          112218.183892
# ..                            ...                 ...                    ...
# 134                  16400.765364         1348.273805          119257.644438
# 135                  15385.373201          972.219932           83053.638845
# 136                  16382.330698         1452.069428           67478.415471
# 137                  15765.064875         1057.313917          131833.310878
# 138                  12402.938880          828.736533           74649.693163
#
# ...

# %%
null_columns = df.columns[df.isnull().any()].tolist()
null_columns
# Out:
# ['frac_trns_pkm_dem_regional_water_borne',
#  'nemomod_entc_residual_capacity_pp_biogas_gw',
#  'frac_trns_pkm_dem_regional_water_borne.1',
#  'frac_inen_energy_agriculture_and_livestock_solar',
#  'frac_inen_energy_agriculture_and_livestock_diesel',
#  'frac_inen_energy_agriculture_and_livestock_coke',
#  'frac_inen_energy_agriculture_and_livestock_solid_biomass',
#  'frac_inen_energy_agriculture_and_livestock_oil',
#  'frac_inen_energy_agriculture_and_livestock_coal',
#  'frac_inen_energy_agriculture_and_livestock_natural_gas',
#  'frac_inen_energy_agriculture_and_livestock_furnace_gas',
#  'frac_inen_energy_agriculture_and_livestock_electricity',
#  'frac_inen_energy_agriculture_and_livestock_gasoline',
#  'frac_inen_energy_cement_gasoline',
#  'frac_inen_energy_cement_natural_gas',
#  'frac_inen_energy_cement_solid_biomass',
#  'frac_inen_energy_cement_coal',
#  'frac_inen_energy_cement_solar',
#  'frac_inen_energy_cement_coke',
#  'frac_inen_energy_cement_kerosene',
# ...

# %%
len(null_columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(null_columns)
#
# NameError: name 'null_columns' is not defined

# %%
zero_columns = df.columns[(df == 0).all()].tolist()
zero_columns
# Out:
# ['nemomod_entc_frac_min_share_production_pp_coal',
#  'nemomod_entc_frac_min_share_production_pp_hydropower',
#  'nemomod_entc_frac_min_share_production_pp_biomass',
#  'nemomod_entc_frac_min_share_production_pp_nuclear',
#  'nemomod_entc_frac_min_share_production_pp_geothermal',
#  'nemomod_entc_frac_min_share_production_pp_ocean',
#  'nemomod_entc_frac_min_share_production_pp_wind',
#  'nemomod_entc_frac_min_share_production_pp_biogas',
#  'nemomod_entc_frac_min_share_production_pp_gas_ccs',
#  'nemomod_entc_frac_min_share_production_pp_waste_incineration',
#  'nemomod_entc_frac_min_share_production_pp_coal_ccs',
#  'frac_trns_pkm_dem_private_and_public_water_borne',
#  'ef_lvst_entferm_chickens_kg_ch4_head',
#  'nemomod_entc_residual_capacity_pp_coal_gw',
#  'nemomod_entc_residual_capacity_pp_waste_incineration_gw',
#  'nemomod_entc_residual_capacity_pp_geothermal_gw',
#  'nemomod_entc_residual_capacity_pp_biomass_gw',
#  'nemomod_entc_residual_capacity_pp_ocean_gw',
# ...

# %%
len(zero_columns)
# Out:
# 90

# %%
df_input = pd.read_csv('experiment_data/input_data/input_estresados_1001.csv')
df_input['frac_inen_energy_agriculture_and_livestock_solar']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# Name: frac_inen_energy_agriculture_and_livestock_solar, dtype: float64

# %%
list_of_missing_values = null_columns + zero_columns

# %%
df = pd.DataFrame()
df['inputs with missing values'] = list_of_missing_values
df
# Out:
#                             inputs with missing values
# 0               frac_trns_pkm_dem_regional_water_borne
# 1          nemomod_entc_residual_capacity_pp_biogas_gw
# 2             frac_trns_pkm_dem_regional_water_borne.1
# 3     frac_inen_energy_agriculture_and_livestock_solar
# 4    frac_inen_energy_agriculture_and_livestock_diesel
# ..                                                 ...
# 345                      frac_inen_energy_mining_solar
# 346    frac_inen_energy_mining_hydrocarbon_gas_liquids
# 347                   frac_inen_energy_mining_kerosene
# 348                       frac_inen_energy_mining_coal
# 349                 emission_co2e_subsector_total_ccsq
#
# [350 rows x 1 columns]

# %%
df.to_csv('inputs_with_missing_values.csv', index=False)
