# %%
from utils import GenerateSensitivityAnalysisData
import pandas as pd
import os

# %%
df = pd.read_csv('experiment_data/output_data/output_estresados_0.csv')
df.head()
# Out:
#    primary_id region  time_period  area_agrc_crops_bevs_and_spices  \
# 0           0   iran            0                     6.640703e+06
# 1           0   iran            1                     5.303445e+06
# 2           0   iran            2                     3.924789e+06
# 3           0   iran            3                     3.149133e+06
# 4           0   iran            4                     2.659890e+06
#
#    area_agrc_crops_cereals  area_agrc_crops_fibers  area_agrc_crops_fruits  \
# 0             1.477131e+07            3.064940e+06            7.988710e+06
# 1             2.293184e+07            2.447744e+06            6.379999e+06
# 2             3.133368e+07            1.811441e+06            4.721488e+06
# 3             3.587921e+07            1.453446e+06            3.788381e+06
# 4             3.843551e+07            1.227642e+06            3.199825e+06
#
#    area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# ...

# %%
df['Year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df['Year']
#
# ...

# %%
generate_data = GenerateSensibilityAnalysisData(experiment_data_path='experiment_data')

# %%
generate_data.create_CSVs_for_sensibility_analysis()
# Out:
#    exports_lvst_cattle_nondairy  exports_lvst_sheep  exports_lvst_chickens  \
# 0                   8670.977601          890.615602           75416.655377
# 1                  13957.952594         1028.627032           99650.832154
# 2                  17572.827427         1125.120028           78685.984594
# 3                  19356.962711         1370.664081          135670.504570
#
#    exports_lvst_cattle_dairy  exports_lvst_mules  exports_lvst_horses  \
# 0               13702.944702         1108.855631          1315.386471
# 1                9252.216045          755.930335          3037.251798
# 2               12891.111174         1138.483447          2506.915357
# 3               12055.765015         1531.086747          1960.450450
#
#    exports_lvst_buffalo  exports_lvst_goats  exports_lvst_pigs  \
# 0           1287.528232         1388.098419        1123.429761
# 1           1440.135318         2422.176187        1212.766857
# ...
